# %% [markdown]
# # **Kenya**

# %% [markdown]
# **Imports and Data Loading**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

df = pd.read_csv("kenya.csv")

df['Country'] = "Kenya"

print(f"Dataset loaded with {df.shape[0]} rows and {df.shape[1]} cols.")
# Out:
# Dataset loaded with 4108 rows and 13 cols.

# %% [markdown]
# **Missing Value Handling & Sentinels**

# %%
df.replace(~999, np.nan, inplace=True)

duplicates = df.duplicated().sum()
df.drop_duplicates(inplace=True)

null_reports = df.isna().sum()
null_percentage = (null_reports / len(df)) * 100

print(f"Duplicates removed: {duplicates}")
print("\nMissing Value Percentage per Column: ", end="")
print(null_percentage[null_percentage > 0])
# Out:
# Duplicates removed: 0
#
# Missing Value Percentage per Column: Series([], dtype: float64)

# %% [markdown]
# **Data Parsing**

# %%
df['Date'] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")

df['Month'] = df['Date'].dt.month

df.set_index('Date', inplace=True)

df.head()
# Out:
#             YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  \
# Date
# 2015-01-01  2015    1  19.56    28.99    12.09      16.90         0.00  45.32
# 2015-01-02  2015    2  19.63    29.77    11.04      18.73         0.00  38.76
# 2015-01-03  2015    3  20.40    30.57    11.71      18.86         0.00  41.75
# 2015-01-04  2015    4  21.33    31.20    13.02      18.18         3.49  51.87
# 2015-01-05  2015    5  20.41    29.52    12.38      17.14         1.79  48.04
#
#             WS2M  WS2M_MAX     PS  QV2M Country  Month
# Date
# 2015-01-01  3.12      4.76  83.68  6.88   Kenya      1
# 2015-01-02  3.23      4.35  83.67  5.85   Kenya      1
# 2015-01-03  3.46      4.68  83.69  6.65   Kenya      1
# 2015-01-04  2.29      4.00  83.62  8.60   Kenya      1
# 2015-01-05  1.77      4.05  83.54  7.64   Kenya      1

# %% [markdown]
# **Outlier Detection**

# %%
cols_to_check = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M', 'WS2M_MAX']

z_scores = np.abs(stats.zscore(df[cols_to_check].dropna()))

outliers = (z_scores > 3).sum()
print(f"Outlier counts: {outliers}")

df.ffill(inplace=True)
# Out:
# Outlier counts: 124
#             YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  \
# Date
# 2015-01-01  2015    1  19.56    28.99    12.09      16.90         0.00  45.32
# 2015-01-02  2015    2  19.63    29.77    11.04      18.73         0.00  38.76
# 2015-01-03  2015    3  20.40    30.57    11.71      18.86         0.00  41.75
# 2015-01-04  2015    4  21.33    31.20    13.02      18.18         3.49  51.87
# 2015-01-05  2015    5  20.41    29.52    12.38      17.14         1.79  48.04
# ...          ...  ...    ...      ...      ...        ...          ...    ...
# 2026-03-27  2026   86  19.37    25.40    15.39      10.01         2.67  81.97
# 2026-03-28  2026   87  19.66    26.40    15.24      11.16         0.59  77.40
# 2026-03-29  2026   88  19.72    26.54    14.41      12.13         0.82  77.71
# 2026-03-30  2026   89  19.68    26.81    13.86      12.95         4.59  79.29
# 2026-03-31  2026   90  19.59    25.54    15.37      10.17         1.29  80.88
#
#             WS2M  WS2M_MAX     PS   QV2M Country  Month
# Date
# 2015-01-01  3.12      4.76  83.68   6.88   Kenya      1
# 2015-01-02  3.23      4.35  83.67   5.85   Kenya      1
# 2015-01-03  3.46      4.68  83.69   6.65   Kenya      1
# 2015-01-04  2.29      4.00  83.62   8.60   Kenya      1
# 2015-01-05  1.77      4.05  83.54   7.64   Kenya      1
# ...          ...       ...    ...    ...     ...    ...
# 2026-03-27  2.47      3.90  84.08  13.40   Kenya      3
# 2026-03-28  1.98      3.37  84.02  12.68   Kenya      3
# 2026-03-29  1.77      3.25  83.88  12.92   Kenya      3
# 2026-03-30  2.01      3.32  83.87  13.16   Kenya      3
# 2026-03-31  2.15      3.58  83.92  13.40   Kenya      3
#
# [4108 rows x 14 columns]

# %% [markdown]
# **Time Series Visualization**

# %%
monthly_temps = df['T2M'].resample('ME').mean()

plt.figure(figsize=(12, 6))
plt.plot(monthly_temps, color='orange', label='Mean Temp (T2M)')

warmest = monthly_temps.idxmax()
coolest = monthly_temps.idxmin()

plt.annotate(f'Warmest: {monthly_temps.max():.2f}°C', xy=(warmest, monthly_temps.max()), 
             xytext=(10, 10), textcoords='offset points', arrowprops=dict(arrowstyle='->'))
plt.annotate(f'Coolest: {monthly_temps.min():.2f}°C', xy=(coolest, monthly_temps.min()), 
             xytext=(10, -15), textcoords='offset points', arrowprops=dict(arrowstyle='->'))

plt.title('Kenya Monthly Mean Temperature Trends (2015-2026)')
plt.ylabel('Temperature (°C)')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **Precipitation Analysis**

# %%
monthly_precip = df['PRECTOTCORR'].resample('ME').sum()

plt.figure(figsize=(12,6))
plt.bar(monthly_precip.index, monthly_precip.values, width=20, color='skyblue')
plt.title('Kenya Monthly Total Precipitation (mm)')
plt.ylabel('Rainfall (mm)')

plt.show()

# %% [markdown]
# **Correlation Heatmap**

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Climate Variable Correlation Heatmap')
plt.show()

# %% [markdown]
# **Exporting Cleaned Data**

# %%
import os
if not os.path.exists('../data'):
    os.makedirs('../data')
df.to_csv("../data/kenya_clean.csv")
print("Cleaned data exported to data/kenya_clean.csv")
# Out:
# Cleaned data exported to data/kenya_clean.csv
